# %% [markdown]
# # Classifying Book Author's gender by name (approximately)

# %% [markdown]
# Used dataset: https://www.kaggle.com/datasets/gracehephzibahm/gender-by-name/data

# %% [markdown]
# In our research project aimed at analyzing the representation of female book authors on WikiData, the initial step involves attempting to deduce the gender of authors based on their names. This process is motivated by the goal of categorizing authors into distinct groups —
# - male authors,
# - female authors,
# - and those whose gender is inconclusive or if a book is associated with collective works.
#
# By doing so, we aim to gain insights into the gender distribution within the dataset, allowing us to later explore the coverage of these authors on WikiData.

# %% [markdown]
# However, it's crucial to acknowledge that gender is a complex and subjective aspect of individual identity. In a proper and respectful context, one should always ask a person about their gender identity. In our case, we recognize the limitations of deducing gender solely based on names and emphasize that our approach serves as a coarse approximation. We understand that gender identity is deeply personal and can't be accurately determined through this method. Our intent is to use name matching as a preliminary step to explore broad patterns in our dataset and initiate a meaningful analysis of gender representation. We approach this with sensitivity and respect for the diverse identities of individuals.

# %%
# %cd ..
# Out:
# C:\Users\jplak\projects\women_books
# C:\Users\jplak\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\Local\pypoetry\Cache\virtualenvs\women-books-tYhTzxuG-py3.10\lib\site-packages\IPython\core\magics\osm.py:417: UserWarning: using dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %% [markdown]
# ## 0. Import Data

# %%
import pandas as pd
from tqdm import tqdm
tqdm.pandas()

# %%
df_names = pd.read_csv("./data/gender_by_name_dataset.csv")

# %%
df_books = pd.read_parquet("./datasets/2024-01-19_books.parquet")

# %%
df_books
# Out:
#               ISBN                                         Book-Title  \
# 0        195153448                                Classical Mythology
# 1          2005018                                       Clara Callan
# 2         60973129                               Decision in Normandy
# 3        374157065  Flu: The Story of the Great Influenza Pandemic...
# 4        393045218                             The Mummies of Urumchi
# ...            ...                                                ...
# 271374   440400988                         There's a Bat in Bunk Five
# 271375   525447644                            From One to One Hundred
# 271376  006008667X  Lily Dale : The True Story of the Town that Ta...
# 271377   192126040                        Republic (World's Classics)
# 271378   767409752  A Guided Tour of Rene Descartes' Meditations o...
#
#                  Book-Author Year-Of-Publication  \
# 0         Mark P. O. Morford                2002
# 1       Richard Bruce Wright                2001
# 2               Carlo D'Este                1991
# 3           Gina Bari Kolata                1999
# 4            E. J. W. Barber                1999
# ...                      ...                 ...
# 271374        Paula Danziger                1988
# 271375            Teri Sloat                1991
# 271376      Christine Wicker                2004
# 271377                 Plato                1996
# 271378   Christopher  Biffle                2000
#
#                                                Publisher  \
# 0                                Oxford University Press
# 1                                  HarperFlamingo Canada
# 2                                        HarperPerennial
# 3                                   Farrar Straus Giroux
# 4                             W. W. Norton &amp; Company
# ...                                                  ...
# 271374                   Random House Childrens Pub (Mm)
# 271375                                      Dutton Books
# 271376                                HarperSanFrancisco
# 271377                           Oxford University Press
# 271378  McGraw-Hill Humanities/Social Sciences/Languages
#
#                                               Image-URL-M  \
# 0       http://images.amazon.com/images/P/0195153448.0...
# 1       http://images.amazon.com/images/P/0002005018.0...
# 2       http://images.amazon.com/images/P/0060973129.0...
# 3       http://images.amazon.com/images/P/0374157065.0...
# 4       http://images.amazon.com/images/P/0393045218.0...
# ...                                                   ...
# 271374  http://images.amazon.com/images/P/0440400988.0...
# 271375  http://images.amazon.com/images/P/0525447644.0...
# 271376  http://images.amazon.com/images/P/006008667X.0...
# 271377  http://images.amazon.com/images/P/0192126040.0...
# 271378  http://images.amazon.com/images/P/0767409752.0...
#
#                      name_chunks matched_female              matched_male  \
# 0                [Mark, Morford]             []                    [Mark]
# 1       [Richard, Bruce, Wright]             []  [Richard, Bruce, Wright]
# 2                [Carlo, D'Este]             []                   [Carlo]
# 3           [Gina, Bari, Kolata]   [Gina, Bari]                        []
# 4                       [Barber]             []                  [Barber]
# ...                          ...            ...                       ...
# 271374         [Paula, Danziger]        [Paula]                        []
# 271375             [Teri, Sloat]         [Teri]                        []
# 271376       [Christine, Wicker]    [Christine]                        []
# 271377                   [Plato]             []                   [Plato]
# 271378     [Christopher, Biffle]             []             [Christopher]
#
#        matched_inconclusive
# 0                        []
# 1                        []
# 2                        []
# 3                        []
# 4                        []
# ...                     ...
# 271374                   []
# 271375                   []
# 271376                   []
# 271377                   []
# 271378                   []
#
# [271379 rows x 10 columns]

# %% [markdown]
# ## 1. Name dataset EDA and preprocessing

# %%
df_names
# Out:
#            Name Gender    Count   Probability
# 0         James      M  5304407  1.451679e-02
# 1          John      M  5260831  1.439753e-02
# 2        Robert      M  4970386  1.360266e-02
# 3       Michael      M  4579950  1.253414e-02
# 4       William      M  4226608  1.156713e-02
# ...         ...    ...      ...           ...
# 147264   Zylenn      M        1  2.736740e-09
# 147265   Zymeon      M        1  2.736740e-09
# 147266   Zyndel      M        1  2.736740e-09
# 147267   Zyshan      M        1  2.736740e-09
# 147268    Zyton      M        1  2.736740e-09
#
# [147269 rows x 4 columns]

# %%
df_names["Gender"].value_counts()
# Out:
# Gender
# F    89749
# M    57520
# Name: count, dtype: int64

# %%
df_female_names[
    (~df_female_names["Name"].str.isalpha())
    & (~df_female_names["Name"].str.contains("-"))
]
# Out:
#               Name Gender  Count   Probability
# 27085        Chlo…      F    247  6.759750e-07
# 31858       Am…Lie      F    180  4.926130e-07
# 42282         Esm…      F     94  2.572540e-07
# 55930          Ku.      F     43  1.176800e-07
# 59234        Ren…E      F     36  9.852270e-08
# ...            ...    ...    ...           ...
# 133622    Yoshoda@      F      1  2.736740e-09
# 133673  Za'Quiesha      F      1  2.736740e-09
# 133782      Ze'Eva      F      1  2.736740e-09
# 133888        Zo'E      F      1  2.736740e-09
# 133889       Zo'Ee      F      1  2.736740e-09
#
# [281 rows x 4 columns]

# %%
df_female_names[
    df_female_names["Name"].str.endswith(".")
]
# Out:
#              Name Gender  Count   Probability
# 55930         Ku.      F     43  1.176800e-07
# 65877         Km.      F     25  6.841850e-08
# 93539       Smts.      F      6  1.642040e-08
# 101918      Miss.      F      5  1.368370e-08
# 101985        Ms.      F      5  1.368370e-08
# 110755       Mrs.      F      4  1.094700e-08
# 111446        Kr.      F      3  8.210220e-09
# 113109       Kum.      F      2  5.473480e-09
# 117455         B.      F      1  2.736740e-09
# 123070         K.      F      1  2.736740e-09
# 126628       Mmt.      F      1  2.736740e-09
# 130634       Shm.      F      1  2.736740e-09
# 130686      Shri.      F      1  2.736740e-09
# 131266  Su.Shree.      F      1  2.736740e-09
# 131463       Sut.      F      1  2.736740e-09

# %%
df_names[df_names["Name"] == "Mark"]
# Out:
#       Name Gender    Count  Probability
# 23    Mark      M  1410637     0.003861
# 4216  Mark      F     4668     0.000013

# %%
name_and_count: pd.Series = df_names.groupby("Name")["Count"].count()
single_sex_names_mask = name_and_count == 1

# %%
single_sex_names = name_and_count[single_sex_names_mask]

# %%
df_names_single_sex = df_names[df_names["Name"].isin(single_sex_names.index)].copy()
df_names_mixed_sex = df_names[~df_names["Name"].isin(single_sex_names.index)].copy()

# %%
df_female_names = df_names_single_sex[df_names_single_sex["Gender"] == "F"].copy()  
df_male_names = df_names_single_sex[df_names_single_sex["Gender"] == "M"].copy()

# %%
print(f'Количество женских имён: {len(df_female_names)}')
print(f'Количество мужских имён: {len(df_male_names)}')
# Out:
# Количество женских имён: 76390
# Количество мужских имён: 44161

# %%
print(df_female_names['Name'].isin(df_male_names['Name']).any())
print(df_male_names['Name'].isin(df_female_names['Name']).any())
# Out:
# False
# False

# %%
df_female_names
# Out:
#             Name Gender  Count   Probability
# 1180     Delilah      F  40776  1.115930e-04
# 1312     Brielle      F  34420  9.419860e-05
# 1348      Helene      F  33317  9.118000e-05
# 1371       Alina      F  32527  8.901800e-05
# 1397        Lyla      F  31401  8.593640e-05
# ...          ...    ...    ...           ...
# 133945     Zyika      F      1  2.736740e-09
# 133946  Zymeliah      F      1  2.736740e-09
# 133947    Zyrije      F      1  2.736740e-09
# 133948   Zyrinah      F      1  2.736740e-09
# 133949      Zyta      F      1  2.736740e-09
#
# [76390 rows x 4 columns]

# %%
df_male_names
# Out:
#              Name Gender  Count   Probability
# 1378        Jakob      M  32249  8.825720e-05
# 1669    Jefferson      M  22397  6.129480e-05
# 1683       Rodger      M  21922  5.999480e-05
# 1764        Romeo      M  19941  5.457330e-05
# 1782      Vicente      M  19616  5.368390e-05
# ...           ...    ...    ...           ...
# 147264     Zylenn      M      1  2.736740e-09
# 147265     Zymeon      M      1  2.736740e-09
# 147266     Zyndel      M      1  2.736740e-09
# 147267     Zyshan      M      1  2.736740e-09
# 147268      Zyton      M      1  2.736740e-09
#
# [44161 rows x 4 columns]

# %%
df_names_mixed_sex
# Out:
#            Name Gender    Count   Probability
# 0         James      M  5304407  1.451679e-02
# 1          John      M  5260831  1.439753e-02
# 2        Robert      M  4970386  1.360266e-02
# 3       Michael      M  4579950  1.253414e-02
# 4       William      M  4226608  1.156713e-02
# ...         ...    ...      ...           ...
# 147222   Ziyuan      M        1  2.736740e-09
# 147224    Zlata      M        1  2.736740e-09
# 147243    Zowie      M        1  2.736740e-09
# 147246     Zozo      M        1  2.736740e-09
# 147249     Zuha      M        1  2.736740e-09
#
# [26718 rows x 4 columns]

# %%
df_names_mixed_sex.sort_values('Name').head(30)
# Out:
#             Name Gender  Count   Probability
# 112246         A      F      2  5.473480e-09
# 114150         A      M      2  5.473480e-09
# 96227      Aaden      F      5  1.368370e-08
# 4119       Aaden      M   4877  1.334710e-05
# 12909       Aadi      M    857  2.345390e-06
# 73983       Aadi      F     16  4.378790e-08
# 73985      Aadyn      F     16  4.378790e-08
# 17807      Aadyn      M    516  1.412160e-06
# 29407    Aalijah      M    212  5.801890e-07
# 34656    Aalijah      F    150  4.105110e-07
# 41991    Aaliyah      M     96  2.627270e-07
# 717      Aaliyah      F  88543  2.423190e-04
# 39625    Aaliyan      F    110  3.010410e-07
# 94127    Aaliyan      M      6  1.642040e-08
# 43712     Aamari      F     86  2.353600e-07
# 37918     Aamari      M    123  3.366190e-07
# 90641      Aamir      F      6  1.642040e-08
# 7357       Aamir      M   2020  5.528220e-06
# 115672     Aanik      F      1  2.736740e-09
# 94128      Aanik      M      6  1.642040e-08
# 16564   Aaradhya      F    578  1.581840e-06
# 133983  Aaradhya      M      1  2.736740e-09
# 24412      Aaren      F    300  8.210220e-07
# 12857      Aaren      M    863  2.361810e-06
# 60926     Aareon      M     33  9.031240e-08
# 83528     Aareon      F     10  2.736740e-08
# 87149       Aari      F      9  2.463070e-08
# 78316       Aari      M     13  3.557760e-08
# 49943     Aarian      F     60  1.642040e-07
# 36801     Aarian      M    132  3.612500e-07

# %%
print(len(df_names_mixed_sex))
# Out:
# 26718

# %%
df_names_mixed_sex['Name'].nunique()
# Out:
# 13359

# %%
name_groups = df_names_mixed_sex.groupby('Name')

# %%
name_groups.get_group('Yury')
# Out:
#        Name Gender  Count   Probability
# 28638  Yury      F    223  6.102930e-07
# 71547  Yury      M     19  5.199810e-08

# %%
mainly_female_name_buffer = set()
mainly_male_name_buffer = set()
inconclusive_name_buffer = set()
for name in tqdm(df_names_mixed_sex['Name'].unique()):
    subframe = name_groups.get_group(name)
    count_male = subframe[subframe['Gender'] == 'M']['Count'].item()
    count_female = subframe[subframe['Gender'] == 'F']['Count'].item()
    share = count_male/count_female - 1
    if share > 0.3:
        mainly_male_name_buffer.add(name)
    elif share < -0.3:
        mainly_female_name_buffer.add(name)
    else: 
        inconclusive_name_buffer.add(name)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████| 13359/13359 [00:06<00:00, 2036.99it/s]

# %%
print(mainly_female_name_buffer.isdisjoint(mainly_male_name_buffer))
print(mainly_female_name_buffer.isdisjoint(inconclusive_name_buffer))
print(inconclusive_name_buffer.isdisjoint(mainly_male_name_buffer))
# Out:
# True
# True
# True

# %%
df_names_single_sex['Name'].isin(mainly_female_name_buffer).any()
# Out:
# False

# %%
print(f'Количество однозначно женских имён: {len(df_female_names)}')
print(f'Количество однозначно мужских имён: {len(df_male_names)}')
print(f'Количество женских имён, определённых как женские: {len(mainly_female_name_buffer)}')
print(f'Количество мужских имён, определённых как мужские: {len(mainly_male_name_buffer)}')
print(f'Количество смешанных имён: {len(inconclusive_name_buffer)}')
# Out:
# Количество однозначно женских имён: 76390
# Количество однозначно мужских имён: 44161
# Количество женских имён, определённых как женские: 6148
# Количество мужских имён, определённых как мужские: 6112
# Количество смешанных имён: 1099

# %% [markdown]
# ## 2. Classification through exact match

# %% [markdown]
# In a proper way, gender is subjective and should be asked of a person. In our research, for the purpose of a coarse approximation, we utilize matching by names. We acknowledge the limitations of this approach and emphasize that our intent is not to make assumptions about individuals' gender identities but rather to explore patterns within the dataset. We respect the personal nature of gender identity and encourage a nuanced understanding of this complex aspect of individual expression.

# %%
female_names_set = set(df_female_names["Name"]).union(mainly_female_name_buffer)

# %%
male_names_set = set(df_male_names["Name"]).union(mainly_male_name_buffer)

# %%
print(female_names_set.isdisjoint(male_names_set))
# Out:
# True

# %%
df_books["name_chunks"] = df_books["Book-Author"].str.split()

# %%
'PHILIP'.title()
# Out:
# 'Philip'

# %%
def filter_chunks(chunk_list):
    return [
        el.title()       #coerse text case 
        for el in chunk_list 
        if not (
            el.endswith(".")
            and len(el) <= 2
        )
    ]

# %%
filter_chunks(["A.", "Miss.", "PHILIP", "PHILIP-JANE", "D'ARTANjaN"])
# Out:
# ['Miss.', 'Philip', 'Philip-Jane', "D'Artanjan"]

# %%
df_books["name_chunks"] = df_books["name_chunks"].progress_apply(filter_chunks)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████| 271379/271379 [00:00<00:00, 296172.51it/s]

# %%
df_books["name_chunks"]
# Out:
# 0                  [Mark, Morford]
# 1         [Richard, Bruce, Wright]
# 2                  [Carlo, D'Este]
# 3             [Gina, Bari, Kolata]
# 4                         [Barber]
#                     ...
# 271374           [Paula, Danziger]
# 271375               [Teri, Sloat]
# 271376         [Christine, Wicker]
# 271377                     [Plato]
# 271378       [Christopher, Biffle]
# Name: name_chunks, Length: 271379, dtype: object

# %%
def check_in_set(chunks: list[str], names=female_names_set) -> list[str]:
    return [name for name in chunks if name in names]

# %%
df_books["matched_female"] = df_books["name_chunks"].progress_apply(check_in_set)
# Out:
# 100%|█████████████████████████████████████████████████████████████████████| 271379/271379 [00:00<00:00, 1038080.59it/s]

# %%
df_books[df_books["matched_female"].apply(bool)]
# Out:
#               ISBN                                         Book-Title  \
# 3        374157065  Flu: The Story of the Great Influenza Pandemic...
# 5        399135782                             The Kitchen God's Wife
# 9       074322678X            Where You'll Find Me: And Other Stories
# 12       887841740                                 The Middle Stories
# 17      1881320189                      Goodbye to the Buttermilk Sky
# ...            ...                                                ...
# 271365   395264707                                         Dreamsnake
# 271373   449906736      Flashpoints: Promise and Peril in a New World
# 271374   440400988                         There's a Bat in Bunk Five
# 271375   525447644                            From One to One Hundred
# 271376  006008667X  Lily Dale : The True Story of the Town that Ta...
#
#               Book-Author Year-Of-Publication  \
# 3        Gina Bari Kolata                1999
# 5                 Amy Tan                1991
# 9             Ann Beattie                2002
# 12            Sheila Heti                2004
# 17           Julia Oliver                1994
# ...                   ...                 ...
# 271365  Vonda N. McIntyre                1978
# 271373       Robin Wright                1993
# 271374     Paula Danziger                1988
# 271375         Teri Sloat                1991
# 271376   Christine Wicker                2004
#
#                               Publisher  \
# 3                  Farrar Straus Giroux
# 5                      Putnam Pub Group
# 9                              Scribner
# 12                House of Anansi Press
# 17                       River City Pub
# ...                                 ...
# 271365                 Houghton Mifflin
# 271373                 Ballantine Books
# 271374  Random House Childrens Pub (Mm)
# 271375                     Dutton Books
# 271376               HarperSanFrancisco
#
#                                               Image-URL-M  \
# 3       http://images.amazon.com/images/P/0374157065.0...
# 5       http://images.amazon.com/images/P/0399135782.0...
# 9       http://images.amazon.com/images/P/074322678X.0...
# 12      http://images.amazon.com/images/P/0887841740.0...
# 17      http://images.amazon.com/images/P/1881320189.0...
# ...                                                   ...
# 271365  http://images.amazon.com/images/P/0395264707.0...
# 271373  http://images.amazon.com/images/P/0449906736.0...
# 271374  http://images.amazon.com/images/P/0440400988.0...
# 271375  http://images.amazon.com/images/P/0525447644.0...
# 271376  http://images.amazon.com/images/P/006008667X.0...
#
#                  name_chunks matched_female matched_male matched_inconclusive
# 3       [Gina, Bari, Kolata]   [Gina, Bari]           []                   []
# 5                 [Amy, Tan]          [Amy]        [Tan]                   []
# 9             [Ann, Beattie]          [Ann]    [Beattie]                   []
# 12            [Sheila, Heti]       [Sheila]           []                   []
# 17           [Julia, Oliver]        [Julia]     [Oliver]                   []
# ...                      ...            ...          ...                  ...
# 271365     [Vonda, Mcintyre]        [Vonda]           []                   []
# 271373       [Robin, Wright]        [Robin]     [Wright]                   []
# 271374     [Paula, Danziger]        [Paula]           []                   []
# 271375         [Teri, Sloat]         [Teri]           []                   []
# 271376   [Christine, Wicker]    [Christine]           []                   []
#
# [119256 rows x 10 columns]

# %%
df_books["matched_male"] = df_books["name_chunks"].progress_apply(lambda x: check_in_set(x, male_names_set))
# Out:
# 100%|█████████████████████████████████████████████████████████████████████| 271379/271379 [00:00<00:00, 1048285.32it/s]

# %%
df_books[df_books["matched_male"].apply(bool)]
# Out:
#               ISBN                                         Book-Title  \
# 0        195153448                                Classical Mythology
# 1          2005018                                       Clara Callan
# 2         60973129                               Decision in Normandy
# 4        393045218                             The Mummies of Urumchi
# 5        399135782                             The Kitchen God's Wife
# ...            ...                                                ...
# 271371  1845170423                                  Cocktail Classics
# 271372  014002803X                                  Anti Death League
# 271373   449906736      Flashpoints: Promise and Peril in a New World
# 271377   192126040                        Republic (World's Classics)
# 271378   767409752  A Guided Tour of Rene Descartes' Meditations o...
#
#                  Book-Author Year-Of-Publication  \
# 0         Mark P. O. Morford                2002
# 1       Richard Bruce Wright                2001
# 2               Carlo D'Este                1991
# 4            E. J. W. Barber                1999
# 5                    Amy Tan                1991
# ...                      ...                 ...
# 271371           David Biggs                2004
# 271372         Kingsley Amis                1975
# 271373          Robin Wright                1993
# 271377                 Plato                1996
# 271378   Christopher  Biffle                2000
#
#                                                Publisher  \
# 0                                Oxford University Press
# 1                                  HarperFlamingo Canada
# 2                                        HarperPerennial
# 4                             W. W. Norton &amp; Company
# 5                                       Putnam Pub Group
# ...                                                  ...
# 271371                                         Connaught
# 271372                                      Viking Press
# 271373                                  Ballantine Books
# 271377                           Oxford University Press
# 271378  McGraw-Hill Humanities/Social Sciences/Languages
#
#                                               Image-URL-M  \
# 0       http://images.amazon.com/images/P/0195153448.0...
# 1       http://images.amazon.com/images/P/0002005018.0...
# 2       http://images.amazon.com/images/P/0060973129.0...
# 4       http://images.amazon.com/images/P/0393045218.0...
# 5       http://images.amazon.com/images/P/0399135782.0...
# ...                                                   ...
# 271371  http://images.amazon.com/images/P/1845170423.0...
# 271372  http://images.amazon.com/images/P/014002803X.0...
# 271373  http://images.amazon.com/images/P/0449906736.0...
# 271377  http://images.amazon.com/images/P/0192126040.0...
# 271378  http://images.amazon.com/images/P/0767409752.0...
#
#                      name_chunks matched_female              matched_male  \
# 0                [Mark, Morford]             []                    [Mark]
# 1       [Richard, Bruce, Wright]             []  [Richard, Bruce, Wright]
# 2                [Carlo, D'Este]             []                   [Carlo]
# 4                       [Barber]             []                  [Barber]
# 5                     [Amy, Tan]          [Amy]                     [Tan]
# ...                          ...            ...                       ...
# 271371            [David, Biggs]             []                   [David]
# 271372          [Kingsley, Amis]             []          [Kingsley, Amis]
# 271373           [Robin, Wright]        [Robin]                  [Wright]
# 271377                   [Plato]             []                   [Plato]
# 271378     [Christopher, Biffle]             []             [Christopher]
#
#        matched_inconclusive
# 0                        []
# 1                        []
# 2                        []
# 4                        []
# 5                        []
# ...                     ...
# 271371                   []
# 271372                   []
# 271373                   []
# 271377                   []
# 271378                   []
#
# [202832 rows x 10 columns]

# %%
df_books["matched_inconclusive"] = df_books["name_chunks"].progress_apply(lambda x: check_in_set(x, inconclusive_name_buffer))
# Out:
# 100%|██████████████████████████████████████████████████████████████████████| 271379/271379 [00:00<00:00, 365365.69it/s]

# %%
df_books[df_books["matched_inconclusive"].apply(bool)].head(30)
# Out:
#             ISBN                                         Book-Title  \
# 105   067976397X                       Corelli's Mandolin : A Novel
# 257     60563079          Peter Pan: The Original Story (Peter Pan)
# 267    312890044                                Moonheart (Newford)
# 388    156528207                                  The Little Prince
# 417    802114369                                      Ohitika Woman
# 446     60804157              He Understanding Masculine Psychology
# 467    870441663  The wild ponies of Assateague Island (Books fo...
# 489    553285343                                  RUSSIA HOUSE, THE
# 514     26329859         From the Earth: Chinese Vegetarian Cooking
# 627    440441501  In the Dinosaur's Paw (Kids of the Polk Street...
# 697    446523992  A Call to Conscience : The Landmark Speeches o...
# 755    451197275                       Saving Private Ryan: A Novel
# 862     60006048  Circle of Three #12: Written in the Stars (Cir...
# 870    307215342  Trixie Belden and the Mystery Off Glen Road (M...
# 912    895872102  The Hauntings of Williamsburg, Yorktown, and J...
# 947    688048730                                  Thinking on paper
# 1007   450029956  Other worlds: The comical history of the state...
# 1047   375420827                                  The Art of Travel
# 1125  3446202218              Kreutzersonate. Eine Liebesgeschichte
# 1196   441366945                                    Imaginary Lands
# 1199    60242388                                      Shape Changer
# 1271  3257250398                                        Konig Babar
# 1272  3257250053                           Die Geschichte Von Babar
# 1327   671679627                            PRIME TIME : PRIME TIME
# 1370   871130297                                 The God of Mirrors
# 1414   385247745            The Power of Myth (Illustrated Edition)
# 1420  037570504X                               Breath, Eyes, Memory
# 1473   486203077               Tales of Terror and the Supernatural
# 1540   671000381                  COURTNEY LOVE: THE QUEEN OF NOISE
# 1541  006101253X                                            Sinners
#
#                     Book-Author Year-Of-Publication  \
# 105          LOUIS DE BERNIERES                1995
# 257                J. M. Barrie                2003
# 267             Charles de Lint                1994
# 388   Antoine de Saint-ExupГ©ry                1968
# 417             Mary Brave Bird                1993
# 446            Robert A Johnson                1977
# 467           Donna K Grosvenor                1975
# 489               JOHN LE CARRE                1990
# 514           Eileen Yin-Fei Lo                1995
# 627        PATRICIA REILLY GIFF                1987
# 697                Kris Shepard                2001
# 755           Max Allan Collins                1998
# 862                 Isobel Bird                2001
# 870              Julie Campbell                1977
# 912       Jackie Eileen Behrend                1998
# 947                 V. A Howard                1986
# 1007         Cyrano de Bergerac                1976
# 1047            Alain de Botton                2002
# 1125           Margriet de Moor                2002
# 1196             Robin McKinley                1985
# 1199              Bill Brittain                1994
# 1271           Jean de Brunhoff                1920
# 1272           Jean de Brunhoff                1920
# 1327               Judy Collins                1989
# 1370              Robert Reilly                1986
# 1414            Joseph Campbell                1988
# 1420           Edwidge Danticat                1998
# 1473             Wilkie Collins                1972
# 1540              Melissa Rossi                1996
# 1541             Jackie Collins                1997
#
#                           Publisher  \
# 105                         Vintage
# 257                  HarperFestival
# 267                       Orb Books
# 388                        Harcourt
# 417                  Pub Group West
# 446         Harpercollins Publisher
# 467     National Geographic Society
# 489                          Bantam
# 514   MacMillan Publishing Company.
# 627                        Yearling
# 697                    Warner Books
# 755                     Signet Book
# 862                            Avon
# 870    Random House Childrens Books
# 912         John F. Blair Publisher
# 947                       W. Morrow
# 1007            New English Library
# 1047                       Pantheon
# 1125                         Hanser
# 1196                      Ace Books
# 1199   Harpercollins Juvenile Books
# 1271                      Not Avail
# 1272                       Diogenes
# 1327                         Pocket
# 1370         Atlantic Monthly Press
# 1414                Doubleday Books
# 1420              Vintage Books USA
# 1473             Dover Publications
# 1540                         Pocket
# 1541                    HarperTorch
#
#                                             Image-URL-M  \
# 105   http://images.amazon.com/images/P/067976397X.0...
# 257   http://images.amazon.com/images/P/0060563079.0...
# 267   http://images.amazon.com/images/P/0312890044.0...
# 388   http://images.amazon.com/images/P/0156528207.0...
# 417   http://images.amazon.com/images/P/0802114369.0...
# 446   http://images.amazon.com/images/P/0060804157.0...
# 467   http://images.amazon.com/images/P/0870441663.0...
# 489   http://images.amazon.com/images/P/0553285343.0...
# 514   http://images.amazon.com/images/P/0026329859.0...
# 627   http://images.amazon.com/images/P/0440441501.0...
# 697   http://images.amazon.com/images/P/0446523992.0...
# 755   http://images.amazon.com/images/P/0451197275.0...
# 862   http://images.amazon.com/images/P/0060006048.0...
# 870   http://images.amazon.com/images/P/0307215342.0...
# 912   http://images.amazon.com/images/P/0895872102.0...
# 947   http://images.amazon.com/images/P/0688048730.0...
# 1007  http://images.amazon.com/images/P/0450029956.0...
# 1047  http://images.amazon.com/images/P/0375420827.0...
# 1125  http://images.amazon.com/images/P/3446202218.0...
# 1196  http://images.amazon.com/images/P/0441366945.0...
# 1199  http://images.amazon.com/images/P/0060242388.0...
# 1271  http://images.amazon.com/images/P/3257250398.0...
# 1272  http://images.amazon.com/images/P/3257250053.0...
# 1327  http://images.amazon.com/images/P/0671679627.0...
# 1370  http://images.amazon.com/images/P/0871130297.0...
# 1414  http://images.amazon.com/images/P/0385247745.0...
# 1420  http://images.amazon.com/images/P/037570504X.0...
# 1473  http://images.amazon.com/images/P/0486203077.0...
# 1540  http://images.amazon.com/images/P/0671000381.0...
# 1541  http://images.amazon.com/images/P/006101253X.0...
#
#                         name_chunks matched_female       matched_male  \
# 105          [Louis, De, Bernieres]             []            [Louis]
# 257                        [Barrie]             []                 []
# 267             [Charles, De, Lint]             []          [Charles]
# 388   [Antoine, De, Saint-Exupг©Ry]             []          [Antoine]
# 417             [Mary, Brave, Bird]         [Mary]            [Brave]
# 446            [Robert, A, Johnson]             []  [Robert, Johnson]
# 467           [Donna, K, Grosvenor]        [Donna]        [Grosvenor]
# 489               [John, Le, Carre]        [Carre]             [John]
# 514           [Eileen, Yin-Fei, Lo]       [Eileen]                 []
# 627        [Patricia, Reilly, Giff]     [Patricia]                 []
# 697                 [Kris, Shepard]             []          [Shepard]
# 755           [Max, Allan, Collins]             []       [Max, Allan]
# 862                  [Isobel, Bird]       [Isobel]                 []
# 870               [Julie, Campbell]        [Julie]                 []
# 912       [Jackie, Eileen, Behrend]       [Eileen]                 []
# 947                     [A, Howard]             []           [Howard]
# 1007         [Cyrano, De, Bergerac]             []           [Cyrano]
# 1047            [Alain, De, Botton]             []            [Alain]
# 1125           [Margriet, De, Moor]     [Margriet]                 []
# 1196              [Robin, Mckinley]        [Robin]                 []
# 1199               [Bill, Brittain]             []             [Bill]
# 1271           [Jean, De, Brunhoff]         [Jean]                 []
# 1272           [Jean, De, Brunhoff]         [Jean]                 []
# 1327                [Judy, Collins]         [Judy]                 []
# 1370               [Robert, Reilly]             []           [Robert]
# 1414             [Joseph, Campbell]             []           [Joseph]
# 1420            [Edwidge, Danticat]             []                 []
# 1473              [Wilkie, Collins]             []           [Wilkie]
# 1540               [Melissa, Rossi]      [Melissa]                 []
# 1541              [Jackie, Collins]             []                 []
#
#      matched_inconclusive
# 105                  [De]
# 257              [Barrie]
# 267                  [De]
# 388                  [De]
# 417                [Bird]
# 446                   [A]
# 467                   [K]
# 489                  [Le]
# 514                  [Lo]
# 627              [Reilly]
# 697                [Kris]
# 755             [Collins]
# 862                [Bird]
# 870            [Campbell]
# 912              [Jackie]
# 947                   [A]
# 1007                 [De]
# 1047                 [De]
# 1125                 [De]
# 1196           [Mckinley]
# 1199           [Brittain]
# 1271                 [De]
# 1272                 [De]
# 1327            [Collins]
# 1370             [Reilly]
# 1414           [Campbell]
# 1420            [Edwidge]
# 1473            [Collins]
# 1540              [Rossi]
# 1541    [Jackie, Collins]

# %%
only_female_matches = (df_books['matched_female'].apply(len) > 0 ) & (df_books['matched_male'].apply(len) == 0) 
df_female_books = df_books[only_female_matches].copy()

# %%
df_female_books
# Out:
#               ISBN                                         Book-Title  \
# 3        374157065  Flu: The Story of the Great Influenza Pandemic...
# 12       887841740                                 The Middle Stories
# 24       439095026                       Tell Me This Isn't Happening
# 33      3442353866    Der Fluch der Kaiserin. Ein Richter- Di- Roman.
# 38       449005615                     Seabiscuit: An American Legend
# ...            ...                                                ...
# 271364   684860112        Driving to Detroit: Memoirs of a Fast Woman
# 271365   395264707                                         Dreamsnake
# 271374   440400988                         There's a Bat in Bunk Five
# 271375   525447644                            From One to One Hundred
# 271376  006008667X  Lily Dale : The True Story of the Town that Ta...
#
#               Book-Author Year-Of-Publication  \
# 3        Gina Bari Kolata                1999
# 12            Sheila Heti                2004
# 24        Robynn Clairday                1999
# 33         Eleanor Cooney                2001
# 38      LAURA HILLENBRAND                2002
# ...                   ...                 ...
# 271364    Lesley Hazleton                1999
# 271365  Vonda N. McIntyre                1978
# 271374     Paula Danziger                1988
# 271375         Teri Sloat                1991
# 271376   Christine Wicker                2004
#
#                                     Publisher  \
# 3                        Farrar Straus Giroux
# 12                      House of Anansi Press
# 24                                 Scholastic
# 33                                   Goldmann
# 38                           Ballantine Books
# ...                                       ...
# 271364  Simon &amp; Schuster (Trade Division)
# 271365                       Houghton Mifflin
# 271374        Random House Childrens Pub (Mm)
# 271375                           Dutton Books
# 271376                     HarperSanFrancisco
#
#                                               Image-URL-M  \
# 3       http://images.amazon.com/images/P/0374157065.0...
# 12      http://images.amazon.com/images/P/0887841740.0...
# 24      http://images.amazon.com/images/P/0439095026.0...
# 33      http://images.amazon.com/images/P/3442353866.0...
# 38      http://images.amazon.com/images/P/0449005615.0...
# ...                                                   ...
# 271364  http://images.amazon.com/images/P/0684860112.0...
# 271365  http://images.amazon.com/images/P/0395264707.0...
# 271374  http://images.amazon.com/images/P/0440400988.0...
# 271375  http://images.amazon.com/images/P/0525447644.0...
# 271376  http://images.amazon.com/images/P/006008667X.0...
#
#                  name_chunks matched_female matched_male matched_inconclusive
# 3       [Gina, Bari, Kolata]   [Gina, Bari]           []                   []
# 12            [Sheila, Heti]       [Sheila]           []                   []
# 24        [Robynn, Clairday]       [Robynn]           []                   []
# 33         [Eleanor, Cooney]      [Eleanor]           []                   []
# 38      [Laura, Hillenbrand]        [Laura]           []                   []
# ...                      ...            ...          ...                  ...
# 271364    [Lesley, Hazleton]       [Lesley]           []                   []
# 271365     [Vonda, Mcintyre]        [Vonda]           []                   []
# 271374     [Paula, Danziger]        [Paula]           []                   []
# 271375         [Teri, Sloat]         [Teri]           []                   []
# 271376   [Christine, Wicker]    [Christine]           []                   []
#
# [55045 rows x 10 columns]

# %%
only_male_matches = (df_books['matched_female'].apply(len) == 0 ) & (df_books['matched_male'].apply(len) > 0) 
df_male_books = df_books[only_male_matches].copy()

# %%
df_male_books
# Out:
#               ISBN                                         Book-Title  \
# 0        195153448                                Classical Mythology
# 1          2005018                                       Clara Callan
# 2         60973129                               Decision in Normandy
# 4        393045218                             The Mummies of Urumchi
# 6        425176428  What If?: The World's Foremost Military Histor...
# ...            ...                                                ...
# 271370  1582380805  Tropical Rainforests: 230 Species in Full Colo...
# 271371  1845170423                                  Cocktail Classics
# 271372  014002803X                                  Anti Death League
# 271377   192126040                        Republic (World's Classics)
# 271378   767409752  A Guided Tour of Rene Descartes' Meditations o...
#
#                   Book-Author Year-Of-Publication  \
# 0          Mark P. O. Morford                2002
# 1        Richard Bruce Wright                2001
# 2                Carlo D'Este                1991
# 4             E. J. W. Barber                1999
# 6               Robert Cowley                2000
# ...                       ...                 ...
# 271370  Allen M., Ph.D. Young                2001
# 271371            David Biggs                2004
# 271372          Kingsley Amis                1975
# 271377                  Plato                1996
# 271378    Christopher  Biffle                2000
#
#                                                Publisher  \
# 0                                Oxford University Press
# 1                                  HarperFlamingo Canada
# 2                                        HarperPerennial
# 4                             W. W. Norton &amp; Company
# 6                               Berkley Publishing Group
# ...                                                  ...
# 271370             Golden Guides from St. Martin's Press
# 271371                                         Connaught
# 271372                                      Viking Press
# 271377                           Oxford University Press
# 271378  McGraw-Hill Humanities/Social Sciences/Languages
#
#                                               Image-URL-M  \
# 0       http://images.amazon.com/images/P/0195153448.0...
# 1       http://images.amazon.com/images/P/0002005018.0...
# 2       http://images.amazon.com/images/P/0060973129.0...
# 4       http://images.amazon.com/images/P/0393045218.0...
# 6       http://images.amazon.com/images/P/0425176428.0...
# ...                                                   ...
# 271370  http://images.amazon.com/images/P/1582380805.0...
# 271371  http://images.amazon.com/images/P/1845170423.0...
# 271372  http://images.amazon.com/images/P/014002803X.0...
# 271377  http://images.amazon.com/images/P/0192126040.0...
# 271378  http://images.amazon.com/images/P/0767409752.0...
#
#                        name_chunks matched_female              matched_male  \
# 0                  [Mark, Morford]             []                    [Mark]
# 1         [Richard, Bruce, Wright]             []  [Richard, Bruce, Wright]
# 2                  [Carlo, D'Este]             []                   [Carlo]
# 4                         [Barber]             []                  [Barber]
# 6                 [Robert, Cowley]             []                  [Robert]
# ...                            ...            ...                       ...
# 271370  [Allen, M.,, Ph.D., Young]             []            [Allen, Young]
# 271371              [David, Biggs]             []                   [David]
# 271372            [Kingsley, Amis]             []          [Kingsley, Amis]
# 271377                     [Plato]             []                   [Plato]
# 271378       [Christopher, Biffle]             []             [Christopher]
#
#        matched_inconclusive
# 0                        []
# 1                        []
# 2                        []
# 4                        []
# 6                        []
# ...                     ...
# 271370                   []
# 271371                   []
# 271372                   []
# 271377                   []
# 271378                   []
#
# [138621 rows x 10 columns]

# %%
unsorted_books = (~df_books['ISBN'].isin(df_female_books['ISBN'])) & (~df_books['ISBN'].isin(df_male_books['ISBN']))
df_unsorted_books = df_books[unsorted_books].copy()

# %%
df_unsorted_books
# Out:
#               ISBN                                         Book-Title  \
# 5        399135782                             The Kitchen God's Wife
# 9       074322678X            Where You'll Find Me: And Other Stories
# 17      1881320189                      Goodbye to the Buttermilk Sky
# 19       452264464               Beloved (Plume Contemporary Fiction)
# 21      1841721522  New Vegetarian: Bold and Beautiful Recipes for...
# ...            ...                                                ...
# 271347   471915645  Introductory Digital Signal Processing with Co...
# 271349  3320016822  Urteil ohne Prozess: Margot Honecker gegen Oss...
# 271352  3525335423                Das Deutsche Kaiserreich 1871-1918.
# 271355  3893312307  Die Vereinten Nationen: Zwischen Anspruch und ...
# 271373   449906736      Flashpoints: Promise and Peril in a New World
#
#                Book-Author Year-Of-Publication  \
# 5                  Amy Tan                1991
# 9              Ann Beattie                2002
# 17            Julia Oliver                1994
# 19           Toni Morrison                1994
# 21      Celia Brooks Brown                2001
# ...                    ...                 ...
# 271347        Paul A. Lynn                1989
# 271349   JГ¶rn Kalkbrenner                1990
# 271352  Hans-Ulrich Wehler                1994
# 271355      GГјnther Unser                1995
# 271373        Robin Wright                1993
#
#                                      Publisher  \
# 5                             Putnam Pub Group
# 9                                     Scribner
# 17                              River City Pub
# 19                                       Plume
# 21               Ryland Peters &amp; Small Ltd
# ...                                        ...
# 271347                   John Wiley &amp; Sons
# 271349                                   Dietz
# 271352              Vandenhoeck &amp; Ruprecht
# 271355  Bundeszentrale fГјr Politische Bildung
# 271373                        Ballantine Books
#
#                                               Image-URL-M  \
# 5       http://images.amazon.com/images/P/0399135782.0...
# 9       http://images.amazon.com/images/P/074322678X.0...
# 17      http://images.amazon.com/images/P/1881320189.0...
# 19      http://images.amazon.com/images/P/0452264464.0...
# 21      http://images.amazon.com/images/P/1841721522.0...
# ...                                                   ...
# 271347  http://images.amazon.com/images/P/0471915645.0...
# 271349  http://images.amazon.com/images/P/3320016822.0...
# 271352  http://images.amazon.com/images/P/3525335423.0...
# 271355  http://images.amazon.com/images/P/3893312307.0...
# 271373  http://images.amazon.com/images/P/0449906736.0...
#
#                    name_chunks matched_female     matched_male  \
# 5                   [Amy, Tan]          [Amy]            [Tan]
# 9               [Ann, Beattie]          [Ann]        [Beattie]
# 17             [Julia, Oliver]        [Julia]         [Oliver]
# 19            [Toni, Morrison]         [Toni]       [Morrison]
# 21      [Celia, Brooks, Brown]        [Celia]  [Brooks, Brown]
# ...                        ...            ...              ...
# 271347            [Paul, Lynn]         [Lynn]           [Paul]
# 271349    [Jг¶Rn, Kalkbrenner]             []               []
# 271352   [Hans-Ulrich, Wehler]             []               []
# 271355       [Gгјnther, Unser]             []               []
# 271373         [Robin, Wright]        [Robin]         [Wright]
#
#        matched_inconclusive
# 5                        []
# 9                        []
# 17                       []
# 19                       []
# 21                       []
# ...                     ...
# 271347                   []
# 271349                   []
# 271352                   []
# 271355                   []
# 271373                   []
#
# [77713 rows x 10 columns]

# %%
df_unsorted_books[(df_unsorted_books['matched_inconclusive'].apply(len) > 0 )]
# Out:
#               ISBN                                         Book-Title  \
# 257       60563079          Peter Pan: The Original Story (Peter Pan)
# 417      802114369                                      Ohitika Woman
# 467      870441663  The wild ponies of Assateague Island (Books fo...
# 489      553285343                                  RUSSIA HOUSE, THE
# 1420    037570504X                               Breath, Eyes, Memory
# ...            ...                                                ...
# 270816  1857939093                                Peter Pan and Wendy
# 270921  2265074217                  Les Experts, tome 1 : Double jeux
# 270999   785300821                     Treasury of Campbell's Recipes
# 271107  8401014441                                  El Jardinero Fiel
# 271163   674356608  Good Natured: The Origins of Right and Wrong i...
#
#                   Book-Author Year-Of-Publication  \
# 257              J. M. Barrie                2003
# 417           Mary Brave Bird                1993
# 467         Donna K Grosvenor                1975
# 489             JOHN LE CARRE                1990
# 1420         Edwidge Danticat                1998
# ...                       ...                 ...
# 270816                 Barrie                1997
# 270921      Max-Allan Collins                2003
# 270999  Campbell Soup Company                1991
# 271107          John Le Carre                2001
# 271163       F. B. M. De Waal                1996
#
#                                Publisher  \
# 257                       HarperFestival
# 417                       Pub Group West
# 467          National Geographic Society
# 489                               Bantam
# 1420                   Vintage Books USA
# ...                                  ...
# 270816                    Pavilion Books
# 270921                       Fleuve noir
# 270999        Publications International
# 271107  Plaza &amp; Janes Editores, S.A.
# 271163          Harvard University Press
#
#                                               Image-URL-M  \
# 257     http://images.amazon.com/images/P/0060563079.0...
# 417     http://images.amazon.com/images/P/0802114369.0...
# 467     http://images.amazon.com/images/P/0870441663.0...
# 489     http://images.amazon.com/images/P/0553285343.0...
# 1420    http://images.amazon.com/images/P/037570504X.0...
# ...                                                   ...
# 270816  http://images.amazon.com/images/P/1857939093.0...
# 270921  http://images.amazon.com/images/P/2265074217.0...
# 270999  http://images.amazon.com/images/P/0785300821.0...
# 271107  http://images.amazon.com/images/P/8401014441.0...
# 271163  http://images.amazon.com/images/P/0674356608.0...
#
#                       name_chunks matched_female matched_male  \
# 257                      [Barrie]             []           []
# 417           [Mary, Brave, Bird]         [Mary]      [Brave]
# 467         [Donna, K, Grosvenor]        [Donna]  [Grosvenor]
# 489             [John, Le, Carre]        [Carre]       [John]
# 1420          [Edwidge, Danticat]             []           []
# ...                           ...            ...          ...
# 270816                   [Barrie]             []           []
# 270921       [Max-Allan, Collins]             []           []
# 270999  [Campbell, Soup, Company]             []           []
# 271107          [John, Le, Carre]        [Carre]       [John]
# 271163                 [De, Waal]             []           []
#
#        matched_inconclusive
# 257                [Barrie]
# 417                  [Bird]
# 467                     [K]
# 489                    [Le]
# 1420              [Edwidge]
# ...                     ...
# 270816             [Barrie]
# 270921            [Collins]
# 270999           [Campbell]
# 271107                 [Le]
# 271163                 [De]
#
# [1588 rows x 10 columns]

# %%
54596+135465+81318
# Out:
# 271379

# %%
55045+138621+77713
# Out:
# 271379

# %% [markdown]
# ## 3. Algorithmic desision function

# %% [markdown]
# Based on a visual analysis of 100 entries, it was noticed that the author's name comes before the surname.
# To resolve the ambiguity in determining the gender of book authors, you can use the following heuristic: if two genders match for one author, then we check - if a fragment of a name that has a match among female names comes before a fragment that has a match among male names, then we consider this author to be a woman. The opposite is also true.

# %%
double_match = (df_unsorted_books['matched_female'].apply(len) > 0 ) & (df_unsorted_books['matched_male'].apply(len) > 0) 
df_double_match = df_unsorted_books[double_match].copy()

# %%
df_double_match
# Out:
#               ISBN                                         Book-Title  \
# 5        399135782                             The Kitchen God's Wife
# 9       074322678X            Where You'll Find Me: And Other Stories
# 17      1881320189                      Goodbye to the Buttermilk Sky
# 19       452264464               Beloved (Plume Contemporary Fiction)
# 21      1841721522  New Vegetarian: Bold and Beautiful Recipes for...
# ...            ...                                                ...
# 271340  3453047192  Die amerikanische Zumutung: PlГ¤doyers gegen d...
# 271341  9813056398      Broken Mirror : True Stories About Drug Abuse
# 271342  000637610X                                   You Got an Ology
# 271347   471915645  Introductory Digital Signal Processing with Co...
# 271373   449906736      Flashpoints: Promise and Peril in a New World
#
#                Book-Author Year-Of-Publication                      Publisher  \
# 5                  Amy Tan                1991               Putnam Pub Group
# 9              Ann Beattie                2002                       Scribner
# 17            Julia Oliver                1994                 River City Pub
# 19           Toni Morrison                1994                          Plume
# 21      Celia Brooks Brown                2001  Ryland Peters &amp; Small Ltd
# ...                    ...                 ...                            ...
# 271340         Rolf Winter                1990                       W. Heyne
# 271341            Dawn Tan                2000                  Angsana Books
# 271342      Maureen Lipman                1990       HarperCollins Publishers
# 271347        Paul A. Lynn                1989          John Wiley &amp; Sons
# 271373        Robin Wright                1993               Ballantine Books
#
#                                               Image-URL-M  \
# 5       http://images.amazon.com/images/P/0399135782.0...
# 9       http://images.amazon.com/images/P/074322678X.0...
# 17      http://images.amazon.com/images/P/1881320189.0...
# 19      http://images.amazon.com/images/P/0452264464.0...
# 21      http://images.amazon.com/images/P/1841721522.0...
# ...                                                   ...
# 271340  http://images.amazon.com/images/P/3453047192.0...
# 271341  http://images.amazon.com/images/P/9813056398.0...
# 271342  http://images.amazon.com/images/P/000637610X.0...
# 271347  http://images.amazon.com/images/P/0471915645.0...
# 271373  http://images.amazon.com/images/P/0449906736.0...
#
#                    name_chunks matched_female     matched_male  \
# 5                   [Amy, Tan]          [Amy]            [Tan]
# 9               [Ann, Beattie]          [Ann]        [Beattie]
# 17             [Julia, Oliver]        [Julia]         [Oliver]
# 19            [Toni, Morrison]         [Toni]       [Morrison]
# 21      [Celia, Brooks, Brown]        [Celia]  [Brooks, Brown]
# ...                        ...            ...              ...
# 271340          [Rolf, Winter]       [Winter]           [Rolf]
# 271341             [Dawn, Tan]         [Dawn]            [Tan]
# 271342       [Maureen, Lipman]      [Maureen]         [Lipman]
# 271347            [Paul, Lynn]         [Lynn]           [Paul]
# 271373         [Robin, Wright]        [Robin]         [Wright]
#
#        matched_inconclusive
# 5                        []
# 9                        []
# 17                       []
# 19                       []
# 21                       []
# ...                     ...
# 271340                   []
# 271341                   []
# 271342                   []
# 271347                   []
# 271373                   []
#
# [64211 rows x 10 columns]

# %%
def decision_func_female(name_chunks: list[str], matched_female: list[str], matched_male: list[str]) -> bool:
    female_indicies: list[int] = [ name_chunks.index(fem_chunk) for fem_chunk in matched_female ]
    male_indicies: list[int] = [ name_chunks.index(male_chunk) for male_chunk in matched_male ]
    if min(female_indicies) < min(male_indicies): return True
    else: return False

# %%
buffer: list[bool] = []
for _, row in tqdm(df_double_match.iterrows(), total=len(df_double_match)):
    decided_female = decision_func_female(
        name_chunks=row.name_chunks,
        matched_female=row.matched_female,
        matched_male=row.matched_male,
    )
    buffer.append(decided_female)

df_double_match['decided_female'] = buffer
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████| 64211/64211 [00:02<00:00, 21711.66it/s]

# %%
df_double_match[df_double_match['decided_female']]
# Out:
#               ISBN                                         Book-Title  \
# 5        399135782                             The Kitchen God's Wife
# 9       074322678X            Where You'll Find Me: And Other Stories
# 17      1881320189                      Goodbye to the Buttermilk Sky
# 19       452264464               Beloved (Plume Contemporary Fiction)
# 21      1841721522  New Vegetarian: Bold and Beautiful Recipes for...
# ...            ...                                                ...
# 271317   792703103          The Hawk of Venice (Atlantic Large Print)
# 271326   441166210                 The Dragon Hoard (Magic Quest, #6)
# 271341  9813056398      Broken Mirror : True Stories About Drug Abuse
# 271342  000637610X                                   You Got an Ology
# 271373   449906736      Flashpoints: Promise and Peril in a New World
#
#                Book-Author Year-Of-Publication                      Publisher  \
# 5                  Amy Tan                1991               Putnam Pub Group
# 9              Ann Beattie                2002                       Scribner
# 17            Julia Oliver                1994                 River City Pub
# 19           Toni Morrison                1994                          Plume
# 21      Celia Brooks Brown                2001  Ryland Peters &amp; Small Ltd
# ...                    ...                 ...                            ...
# 271317     Sally Wentworth                1990             Chivers North Amer
# 271326          Tanith Lee                1984                          Tempo
# 271341            Dawn Tan                2000                  Angsana Books
# 271342      Maureen Lipman                1990       HarperCollins Publishers
# 271373        Robin Wright                1993               Ballantine Books
#
#                                               Image-URL-M  \
# 5       http://images.amazon.com/images/P/0399135782.0...
# 9       http://images.amazon.com/images/P/074322678X.0...
# 17      http://images.amazon.com/images/P/1881320189.0...
# 19      http://images.amazon.com/images/P/0452264464.0...
# 21      http://images.amazon.com/images/P/1841721522.0...
# ...                                                   ...
# 271317  http://images.amazon.com/images/P/0792703103.0...
# 271326  http://images.amazon.com/images/P/0441166210.0...
# 271341  http://images.amazon.com/images/P/9813056398.0...
# 271342  http://images.amazon.com/images/P/000637610X.0...
# 271373  http://images.amazon.com/images/P/0449906736.0...
#
#                    name_chunks matched_female     matched_male  \
# 5                   [Amy, Tan]          [Amy]            [Tan]
# 9               [Ann, Beattie]          [Ann]        [Beattie]
# 17             [Julia, Oliver]        [Julia]         [Oliver]
# 19            [Toni, Morrison]         [Toni]       [Morrison]
# 21      [Celia, Brooks, Brown]        [Celia]  [Brooks, Brown]
# ...                        ...            ...              ...
# 271317      [Sally, Wentworth]        [Sally]      [Wentworth]
# 271326           [Tanith, Lee]       [Tanith]            [Lee]
# 271341             [Dawn, Tan]         [Dawn]            [Tan]
# 271342       [Maureen, Lipman]      [Maureen]         [Lipman]
# 271373         [Robin, Wright]        [Robin]         [Wright]
#
#        matched_inconclusive  decided_female
# 5                        []            True
# 9                        []            True
# 17                       []            True
# 19                       []            True
# 21                       []            True
# ...                     ...             ...
# 271317                   []            True
# 271326                   []            True
# 271341                   []            True
# 271342                   []            True
# 271373                   []            True
#
# [56681 rows x 11 columns]

# %%
df_double_match['decided_male'] = ~df_double_match['decided_female']

# %%
df_double_match
# Out:
#               ISBN                                         Book-Title  \
# 5        399135782                             The Kitchen God's Wife
# 9       074322678X            Where You'll Find Me: And Other Stories
# 17      1881320189                      Goodbye to the Buttermilk Sky
# 19       452264464               Beloved (Plume Contemporary Fiction)
# 21      1841721522  New Vegetarian: Bold and Beautiful Recipes for...
# ...            ...                                                ...
# 271340  3453047192  Die amerikanische Zumutung: PlГ¤doyers gegen d...
# 271341  9813056398      Broken Mirror : True Stories About Drug Abuse
# 271342  000637610X                                   You Got an Ology
# 271347   471915645  Introductory Digital Signal Processing with Co...
# 271373   449906736      Flashpoints: Promise and Peril in a New World
#
#                Book-Author Year-Of-Publication                      Publisher  \
# 5                  Amy Tan                1991               Putnam Pub Group
# 9              Ann Beattie                2002                       Scribner
# 17            Julia Oliver                1994                 River City Pub
# 19           Toni Morrison                1994                          Plume
# 21      Celia Brooks Brown                2001  Ryland Peters &amp; Small Ltd
# ...                    ...                 ...                            ...
# 271340         Rolf Winter                1990                       W. Heyne
# 271341            Dawn Tan                2000                  Angsana Books
# 271342      Maureen Lipman                1990       HarperCollins Publishers
# 271347        Paul A. Lynn                1989          John Wiley &amp; Sons
# 271373        Robin Wright                1993               Ballantine Books
#
#                                               Image-URL-M  \
# 5       http://images.amazon.com/images/P/0399135782.0...
# 9       http://images.amazon.com/images/P/074322678X.0...
# 17      http://images.amazon.com/images/P/1881320189.0...
# 19      http://images.amazon.com/images/P/0452264464.0...
# 21      http://images.amazon.com/images/P/1841721522.0...
# ...                                                   ...
# 271340  http://images.amazon.com/images/P/3453047192.0...
# 271341  http://images.amazon.com/images/P/9813056398.0...
# 271342  http://images.amazon.com/images/P/000637610X.0...
# 271347  http://images.amazon.com/images/P/0471915645.0...
# 271373  http://images.amazon.com/images/P/0449906736.0...
#
#                    name_chunks matched_female     matched_male  \
# 5                   [Amy, Tan]          [Amy]            [Tan]
# 9               [Ann, Beattie]          [Ann]        [Beattie]
# 17             [Julia, Oliver]        [Julia]         [Oliver]
# 19            [Toni, Morrison]         [Toni]       [Morrison]
# 21      [Celia, Brooks, Brown]        [Celia]  [Brooks, Brown]
# ...                        ...            ...              ...
# 271340          [Rolf, Winter]       [Winter]           [Rolf]
# 271341             [Dawn, Tan]         [Dawn]            [Tan]
# 271342       [Maureen, Lipman]      [Maureen]         [Lipman]
# 271347            [Paul, Lynn]         [Lynn]           [Paul]
# 271373         [Robin, Wright]        [Robin]         [Wright]
#
#        matched_inconclusive  decided_female  decided_male
# 5                        []            True         False
# 9                        []            True         False
# 17                       []            True         False
# 19                       []            True         False
# 21                       []            True         False
# ...                     ...             ...           ...
# 271340                   []           False          True
# 271341                   []            True         False
# 271342                   []            True         False
# 271347                   []           False          True
# 271373                   []            True         False
#
# [64211 rows x 12 columns]

# %%
df_female_books_detected = df_double_match[df_double_match['decided_female']].copy()
df_male_books_detected = df_double_match[df_double_match['decided_male']].copy()

# %% [markdown]
# ## 4. Leftovers

# %% [markdown]
# The books I could not detect gender for.

# %%
unmatch = (df_unsorted_books['matched_female'].apply(len) == 0 ) & (df_unsorted_books['matched_male'].apply(len) == 0) 
df_unmatch = df_unsorted_books[unmatch].copy()

# %%
df_unmatch
# Out:
#               ISBN                                         Book-Title  \
# 82      087113375X  Modern Manners: An Etiquette Book for Rude People
# 84       743403843                                           Decipher
# 176     3150000335                                   Kabale Und Liebe
# 257       60563079          Peter Pan: The Original Story (Peter Pan)
# 279      394586239                              Possession: A Romance
# ...            ...                                                ...
# 271251   721402712          Little Red Riding Hood (Well Loved Tales)
# 271337   375415343                                  A Whistling Woman
# 271349  3320016822  Urteil ohne Prozess: Margot Honecker gegen Oss...
# 271352  3525335423                Das Deutsche Kaiserreich 1871-1918.
# 271355  3893312307  Die Vereinten Nationen: Zwischen Anspruch und ...
#
#                Book-Author Year-Of-Publication  \
# 82           P.J. O'Rourke                1990
# 84             Stel Pavlou                2002
# 176               Schiller                   0
# 257           J. M. Barrie                2003
# 279            A. S. Byatt                1990
# ...                    ...                 ...
# 271251     Ladybird Series                1982
# 271337          A.S. BYATT                2002
# 271349   JГ¶rn Kalkbrenner                1990
# 271352  Hans-Ulrich Wehler                1994
# 271355      GГјnther Unser                1995
#
#                                      Publisher  \
# 82                      Atlantic Monthly Press
# 84       Simon &amp; Schuster (Trade Division)
# 176            Philipp Reclam, Jun Verlag GmbH
# 257                             HarperFestival
# 279                           Random House Inc
# ...                                        ...
# 271251                          Ladybird Books
# 271337                                   Knopf
# 271349                                   Dietz
# 271352              Vandenhoeck &amp; Ruprecht
# 271355  Bundeszentrale fГјr Politische Bildung
#
#                                               Image-URL-M  \
# 82      http://images.amazon.com/images/P/087113375X.0...
# 84      http://images.amazon.com/images/P/0743403843.0...
# 176     http://images.amazon.com/images/P/3150000335.0...
# 257     http://images.amazon.com/images/P/0060563079.0...
# 279     http://images.amazon.com/images/P/0394586239.0...
# ...                                                   ...
# 271251  http://images.amazon.com/images/P/0721402712.0...
# 271337  http://images.amazon.com/images/P/0375415343.0...
# 271349  http://images.amazon.com/images/P/3320016822.0...
# 271352  http://images.amazon.com/images/P/3525335423.0...
# 271355  http://images.amazon.com/images/P/3893312307.0...
#
#                   name_chunks matched_female matched_male matched_inconclusive
# 82           [P.J., O'Rourke]             []           []                   []
# 84             [Stel, Pavlou]             []           []                   []
# 176                [Schiller]             []           []                   []
# 257                  [Barrie]             []           []             [Barrie]
# 279                   [Byatt]             []           []                   []
# ...                       ...            ...          ...                  ...
# 271251     [Ladybird, Series]             []           []                   []
# 271337          [A.S., Byatt]             []           []                   []
# 271349   [Jг¶Rn, Kalkbrenner]             []           []                   []
# 271352  [Hans-Ulrich, Wehler]             []           []                   []
# 271355      [Gгјnther, Unser]             []           []                   []
#
# [13502 rows x 10 columns]

# %%
13502/271379*100
# Out:
# 4.975329704951378
